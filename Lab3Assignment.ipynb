# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %% [markdown]
# # Task 1 - Logistic Regression

# %% [markdown]
# **Make Dataset**

# %%
plt.figure(figsize=(8, 8))
plt.subplots_adjust(bottom=.05, top=.9, left=.05, right=.95)
plt.title("Two informative features, one cluster per class", fontsize='small')

X1, Y1 = make_classification(n_samples=1000, n_features=2, n_redundant=2, n_informative=2,
                             n_clusters_per_class=1)
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-1bc0aefdac83> in <module>
#       3 plt.title("Two informative features, one cluster per class", fontsize='small')
#       4
# ----> 5 X1, Y1 = make_classification(n_samples=1000, n_features=2, n_redundant=2, n_informative=2,
#       6                              n_clusters_per_class=1)
#       7 plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/datasets/_samples_generator.py in make_classification(n_samples, n_features, n_informative, n_redundant, n_repeated, n_classes, n_clusters_per_class, weights, flip_y, class_sep, hypercube, shift, scale, shuffle, random_state)
#     160     # Count features, clusters and samples
#     161     if n_informative + n_redundant + n_repeated > n_features:
# --> 162         raise ValueError("Number of informative, redundant and repeated "
#     163                          "features must sum to less than the number of total"
#     164                          " features")
#
# ValueError: Number of informative, redundant and repeated features must sum to less than the number of total features
